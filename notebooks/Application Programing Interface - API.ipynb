# %% [markdown]
# ## Application Programing Interface (API)

# %% [markdown]
# ### API

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Rest API

# %% [markdown]
# ![image.png](attachment:image.png)
